# %%
from collections import namedtuple, defaultdict
import numpy as np
from enum import Enum

# %%
class DataLine:
    def __init__(self, 
                 page_number: str=None, #:Nстраницы
                 line_number: str=None, #:Nстроки, сквозной
                 first_symbol: str=None, #:Nсимвола, начального, сквозной
                 int_from_prev: str=None, #:дельта-v-coord-up 
                 int_from_next: str=None, #:дельта-v-coord-down
                 h_left: str=None, #:h-coord начала
                 h_right: str=None, #:h-coord конца + 1
                 v: str=None, #:v-coord
                 font0_size: str=None, #:font-height0
                 font0_name: str='', #:font-name0
                 font1_size: str=None, #:font-height1
                 font1_name: str='', #:font-name1
                 text: str=None, #:TEXT
                ):
        self.page_number = int(page_number) if len(page_number) else 0
        self.line_number = int(line_number) if len(line_number) else 0
        self.first_symbol = int(first_symbol) if len(first_symbol) else 0
        
        self.int_from_prev = int(int_from_prev) if len(int_from_prev) else 0
        self.int_from_next = int(int_from_next) if len(int_from_next) else 0
        
        self.h_left = int(h_left) if len(h_left) else 0
        self.h_right = int(h_right) if len(h_right) else 0
        self.v = int(v) if len(v) else 0
        
        self.font0_size = int(font0_size) if len(font0_size) else 0
        self.font0_name = font0_name
        self.font1_size = int(font1_size) if len(font1_size) else 0
        self.font1_name = font1_name
        
        self.text = text
        
        self.label = '?'

# %%
structure_file_name = 'processed/aerospace/y:2015:i:1:p:31-57.json'

# %%
data = []

with open(structure_file_name, "r", encoding="utf8") as read_file:
    for line in read_file:
        splitted = line.replace('\n', '').split(':')
        #print(splitted, "LEN", len(splitted))

        if len(splitted) > 13:
            rt = ':'.join(splitted[12:])
            data_line = DataLine(*splitted[:12], rt)
        elif len(splitted) == 13:
            data_line = DataLine(*splitted)
        else:
            pass
            assert len(splitted) >= 12, 'must have at least 12 elements'
        data.append(data_line)

# %%
len(data)
# Out:
# 975

# %% [markdown]
# **Notation**:
#
# - A --- paragraph starts
# - B --- paragraph continues
# - C --- header starts
# - D --- bukvitsa
# - ? --- other

# %% [markdown]
# # Нахождение отступа основного текста
#
# Основной текст (в одноколочных публикациях) должен находиться левее всего.

# %% [markdown]
# Рассмотрим массивы со значениями левого и правого отступов от краев страницы для всех строк документа и выделим m наиболее частотных (для обоих массивов). При этом число m можно выбирать, основываясь на статистике документа. Если в тексте n колонок, то должно быть подавляющее большинство строк, отступы которых попали в топ-m.
#
# Далее для каждой строки делаем так: если строка начинается в одном из топ-m левых значений AND заканчивается в одном из топ-m правых значений [и при этом еще, например, написала самым частым шрифтом], то это — середина абзаца. Если выполняется первое условие, а координаты правой части не попадают в топ-m, то это конец абзаца.
# Наконец, если левая граница не входит в топ-m левых, а правая входит в топ-m правых, то это — начало абзаца.
#
# Случай с буквицей можно обработать как-нибудь отдельно. Это более-менее общие правила, которые, как мне кажется, должны работать везде.
#
# Заголовки при таком подходе тоже определяются просто. Во-первых, они должны быть набраны не самым частым шрифтом, во-вторых, обычно отступ справа у них не попадает в топ-m.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
indents_left = np.array([x.h_left for x in data])
indents_right = np.array([x.h_right for x in data])

# %%
print(np.sort(indents_right)[::2])
# Out:
# [ 63  63  65  66  81  86  93  93  93  93  93  93  93  93  93  96  98 111
#  112 126 128 142 148 153 157 161 163 163 164 167 167 170 174 179 183 184
#  185 190 193 196 197 201 202 208 211 212 213 214 220 223 226 226 226 228
#  229 234 235 236 236 240 241 242 248 249 251 252 252 255 256 259 259 261
#  261 262 264 264 266 267 267 268 269 270 270 271 273 274 274 276 277 279
#  282 282 283 283 286 287 287 289 289 290 291 294 294 296 298 298 298 298
#  298 299 300 302 303 304 306 306 307 308 309 311 312 312 314 315 315 316
#  316 318 319 319 319 319 320 320 321 321 322 322 322 323 324 324 325 326
#  327 328 328 329 329 331 332 333 334 335 337 337 337 338 339 342 342 343
#  343 345 346 349 352 352 352 353 355 358 361 365 366 367 369 370 371 372
#  375 379 379 381 382 385 385 387 388 389 390 390 394 395 395 397 398 400
#  404 405 406 407 410 412 413 413 416 419 421 422 426 429 431 432 433 434
#  437 437 440 443 445 449 452 453 455 455 457 460 461 464 465 468 470 472
#  476 479 480 484 484 489 491 492 497 500 502 503 503 503 503 503 503 503
#  504 504 504 504 509 510 511 512 512 514 515 516 516 516 517 517 520 523
#  523 523 524 524 526 526 526 527 527 528 528 528 529 529 529 529 529 530
#  530 531 531 532 532 532 532 532 532 532 532 532 532 532 532 532 532 532
#  532 532 532 532 532 532 532 532 532 532 532 532 532 532 532 532 532 532
#  532 532 532 532 532 532 532 532 532 532 532 532 532 532 532 532 532 532
#  532 532 532 532 532 532 533 533 533 533 533 533 533 533 533 533 533 533
#  533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533
#  533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533
#  533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533
#  533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533
#  533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533
#  533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533 533
#  534 534 534 534 534 534 534 534 534 534 534 534 534 534 535 535 535 535
#  536 537]

# %% [markdown]
# Здесь можно для каждого журнала найти [и захардкодить] "важные" значения: отступы для основного текста, для начал абзацев, ...
#
# Мы попытаемся определять эти границы при помощи некоторой статистики.

# %%
margin_lefts = np.array([x.h_left for x in data])

unique_margin_lefts, pos_margin_lefts = np.unique(margin_lefts, return_inverse=True)
counts_margin_lefts = np.bincount(pos_margin_lefts)
sorted_margin_lefts = np.argsort(counts_margin_lefts)[::-1]


margin_rights = np.array([x.h_right for x in data])

unique_margin_rights, pos_margin_rights = np.unique(margin_rights, return_inverse=True)
counts_margin_rights = np.bincount(pos_margin_rights)
sorted_margin_rights = np.argsort(counts_margin_rights)[::-1]

# %% [markdown]
# ## Ищем предполагаемые границы абзацев.

# %%
EPS = 4

left_keys = list()
left_indents = defaultdict(int)
for a, b in zip(unique_margin_lefts[sorted_margin_lefts[:15]], counts_margin_lefts[sorted_margin_lefts[:15]]):
    index = -1
    print(a, b)
    for l in range(a - EPS, a + EPS + 1):
        if l in left_indents:
            index = l
    if index != -1:
        left_indents[index] += b
    else:
        left_indents[a] += b
        left_keys.append(a)

left_len = 1
left_sum = left_indents[left_keys[0]]
while True:
    if left_indents[left_keys[left_len]] * 1.2 >= left_indents[left_keys[left_len - 1]]:
        left_sum += left_indents[left_keys[left_len]]
        left_len += 1
    else:
        break
        
print(left_len)


right_keys = list()
right_indents = defaultdict(int)
for a, b in zip(unique_margin_rights[sorted_margin_rights[:15]], counts_margin_rights[sorted_margin_rights[:15]]):
    index = -1
    print(a, b)
    for l in range(a - EPS, a + EPS + 1):
        if l in right_indents:
            index = l
    if index != -1:
        right_indents[index] += b
    else:
        right_indents[a] += b
        right_keys.append(a)

right_len = 1
right_sum = right_indents[right_keys[0]]
while True:
    if right_indents[right_keys[right_len]] * 1.2 >= right_indents[right_keys[right_len - 1]]:
        right_sum += right_indents[right_keys[left_len]]
        right_len += 1
    else:
        break
        
print(right_len)
# Out:
# 62 355
# 90 162
# 83 67
# 98 19
# 72 19
# 317 15
# 80 12
# 66 6
# 331 6
# 296 6
# 313 6
# 309 6
# 262 5
# 310 5
# 265 5
# 1
# 533 241
# 532 113
# 534 28
# 93 18
# 503 13
# 298 10
# 529 10
# 504 8
# 319 8
# 535 7
# 526 7
# 528 6
# 516 6
# 352 6
# 322 5
# 1

# %%
assert left_len == right_len

# %%
left_keys, right_keys
# Out:
# ([62, 90, 83, 98, 72, 317, 331, 296, 309, 262],
#  [533, 93, 503, 298, 319, 526, 516, 352])

# %%
LEFT_BORDERS = np.sort(left_keys[:left_len])
RIGHT_BORDERS = np.sort(right_keys[:right_len])

# %%
LEFT_BORDERS, RIGHT_BORDERS
# Out:
# (array([62]), array([533]))

# %%
AVG_PARAGRAPH_LEN = np.mean(RIGHT_BORDERS - LEFT_BORDERS)

# %%
AVG_PARAGRAPH_LEN
# Out:
# 471.0

# %%
LEFT_MAGRINS = unique_margin_lefts[sorted_margin_lefts[len(LEFT_BORDERS):2 * len(LEFT_BORDERS)]]

# %%
LEFT_MAGRINS
# Out:
# array([90])

# %% [markdown]
# # Определение шрифта основного текста
#
# Это должен быть самый частый шрифт для строк с основным текстом.

# %% [raw]
# # реализация в предположении, что этот шрифт самый частотный во всем документе
# # для статей с большим числом формул это может быть неверно
#
# font_types = np.array([x.font_type for x in data])
#
# unique_font_types, pos_font_types = np.unique(font_types, return_inverse=True)
# counts_font_types = np.bincount(pos_font_types)
# REGULAR_FONT_TYPE = unique_font_types[counts_font_types.argmax()]

# %%
font_names = defaultdict(int)

REGULAR_FONT_NAME = None
REGULAR_FONT_SIZE = None
max_font_name = 0

for x in data:
    if min(abs(x.h_left - LEFT_BORDERS)) <= EPS and min(abs(x.h_right - RIGHT_BORDERS)) <= EPS:
        # чтобы уж наверняка, выбираем только полные строки
        font_names[(x.font0_name, x.font0_size)] += 1
        font_names[(x.font1_name, x.font1_size)] += 1
        if font_names[(x.font0_name, x.font0_size)] > max_font_name:
            max_font_name = font_names[(x.font0_name, x.font0_size)]
            REGULAR_FONT_NAME = x.font0_name
            REGULAR_FONT_SIZE = x.font0_size
        if font_names[(x.font1_name, x.font1_size)] > max_font_name:
            max_font_name = font_names[(x.font1_name, x.font1_size)]
            REGULAR_FONT_NAME = x.font1_name
            REGULAR_FONT_SIZE = x.font1_size

# %%
REGULAR_FONT_NAME, REGULAR_FONT_SIZE
# Out:
# ('g_d0_f1', 12)

# %% [markdown]
# # Процессинг документа (первичный)

# %%
class State(Enum):
    NEUTRAL = 0
    PARAGRAPH = 1
    BUKVITSA = 2

class Label(Enum):
    PAR_STARTS = 'A'
    PAR_CONTINUES = 'B'
    HEADER = 'C'
    BUKVITSA = 'D'
    LIST = 'E'
    OTHER = '?'

cur_state = State["NEUTRAL"]

# %%
EPS = 4
EPS_FONT = 2

# %%
def process_line(line, cur_state):
    # ищем колонку, куда помещается строчка
    ind_block = -1
    for i in range(len(LEFT_BORDERS)):
        l = LEFT_BORDERS[i]
        r = RIGHT_BORDERS[i]
        if l - EPS <= line.h_left and line.h_right <= r + EPS:
            ind_block = i
    
    # если колонка не обнаружена, выходим
    if ind_block == -1:
        return Label["OTHER"], State["NEUTRAL"]
    
    # иначе колонка найдена

    
    is_font0_same = abs(line.font0_size - REGULAR_FONT_SIZE) <= EPS_FONT
    is_font1_same = abs(line.font1_size - REGULAR_FONT_SIZE) <= EPS_FONT
    
    is_font0_regular = line.font0_name == REGULAR_FONT_NAME
    is_font1_regular = line.font1_name == REGULAR_FONT_NAME
    
    is_aligned_left = abs(LEFT_BORDERS[ind_block] - line.h_left) <= EPS
    is_aligned_right = abs(RIGHT_BORDERS[ind_block] - line.h_right) <= EPS
    
    bukvitsa_size = 4000
    
    if is_aligned_left and is_aligned_right:
        if is_font0_same or is_font1_same:
            return Label["PAR_CONTINUES"], State["PARAGRAPH"]
        else:
            return Label["OTHER"], State["NEUTRAL"]
    elif is_aligned_left:
        # конец абзаца
        if is_font0_same or is_font1_same:
            return Label["PAR_CONTINUES"], State["PARAGRAPH"]
        # буквица
        elif abs(line.font0_size - bukvitsa_size) <= EPS or abs(line.font1_size - bukvitsa_size) <= EPS:
            return Label["BUKVITSA"], State["BUKVITSA"]
        # заголовок
        else:
            if (not is_font0_regular) or (not is_font1_regular):
                return Label["HEADER"], State["NEUTRAL"]
            else:
                return Label["OTHER"], State["NEUTRAL"]
    elif is_aligned_right:
        if cur_state == State["BUKVITSA"]:
            return Label["PAR_CONTINUES"], State["PARAGRAPH"]
        elif is_font0_same or is_font1_same:
            tokens = line.text.split()
            if len(tokens) > 0:
                first_token = tokens[0]
                filtered = ''.join(list(filter(lambda x: x in 'ЁЙЦУКЕНГШЩЗХЪФЫВАПРОЛДЖЭЯЧСМИТЬБЮ', first_token)))
                if len(filtered) > 0:
                    return Label["PAR_STARTS"], State["PARAGRAPH"]
                else:
                    return Label["LIST"], State["PARAGRAPH"]
            else:
                return Label["OTHER"], State["NEUTRAL"]
        # заголовок
        else:
            return Label["HEADER"], State["NEUTRAL"]
    else:
        if (not is_font0_regular) and (not is_font1_regular):
            return Label["HEADER"], State["NEUTRAL"]
        else:
            tokens = line.text.split()
            if len(tokens) > 0:
                first_token = tokens[0]
                filtered = ''.join(list(filter(lambda x: x in 'ЁЙЦУКЕНГШЩЗХЪФЫВАПРОЛДЖЭЯЧСМИТЬБЮ', first_token)))
                if len(filtered) > 0:
                    return Label["OTHER"], State["NEUTRAL"]
                else:
                    return Label["LIST"], State["PARAGRAPH"]
            else:
                return Label["OTHER"], State["NEUTRAL"]

# %% [markdown]
# # Процессинг документа (вторичный): чистка заголовков
# После заголовка должен идти абзац.

# %% [raw]
# for i, line in enumerate(data[:-1]):
#     if line.label == 'C':
#         if data[i + 1].label in ['A', 'C']:
#             continue
#         else:
#             line.label = '?'

# %%
Label["OTHER"].value
# Out:
# '?'

# %%
def write_labeled(output_file_name=None):
    if output_file_name is None:
        output_file_name = structure_file_name[:-5] + '_l' + structure_file_name[-5:]
    with open(output_file_name, 'w', encoding='utf8') as output:
        cur_state = State["NEUTRAL"]
        
        PAR_INDENTS = defaultdict(int)
        
        for line in data:
            label, cur_state = process_line(line, cur_state)
            line.label = label.value
            if label == Label["PAR_STARTS"]:
                index = line.h_left
                for l in range(line.h_left - EPS, line.h_left + EPS + 1):
                    if l in PAR_INDENTS:
                        index = l
                PAR_INDENTS[index] += 1
        
        #print(PAR_INDENTS)
        
        for line in data:
            if line.label == Label["OTHER"].value:
                #print('YES', line.text)
                index = line.h_left
                for l in range(line.h_left - EPS, line.h_left + EPS + 1):
                    if l in PAR_INDENTS:
                        index = l
                #print(index)
                if PAR_INDENTS[index] > 1:
                    line.label = Label["PAR_STARTS"].value
        
        
        #bukv_found = False
        #for i in range(len(data) - 1, 0, -1):
        #    if bukv_found:
        #        data[i].label = Label["OTHER"]
        #    elif data[i].label == Label["BUKVITSA"]:
        #        bukv_found = True
        #    elif data[i - 1].label == Label["HEADER"]:
        #        if data[i].label not in [Label["PAR_STARTS"], Label["HEADER"]]:
        #            data[i - 1].label = Label["OTHER"]
        #        elif data[i].label == Label["HEADER"]:
        #            data[i].font0_name != 
            
            
        
        for line in data:
            line_export = [line.page_number, line.line_number, line.first_symbol, line.int_from_prev, 
                           line.int_from_next, line.h_left, line.h_right, line.v,
                           line.font0_size, line.font0_name, line.font1_size, line.font1_name,
                           line.label, line.text]

            line_export = ':'.join([str(y) for y in line_export])
            output.write(f'{line_export}\n')

# %%
write_labeled()

# %%
import io
from reportlab.pdfgen import canvas
from PyPDF2 import PdfFileWriter, PdfFileReader

# %%
def draw_rectaingles(lines, input_file_name, output_file_name=None):
    if output_file_name is None:
        output_file_name = structure_file_name[:-4] + '_l' + structure_file_name[-4:]
    
    color_dict = {'A': (1.0, 0.0, 0.0),
                  'B': (0.0, 0.1, 0.0),
                  'C': (0.0, 0.0, 1.0),
                  'D': (1.0, 0.0, 1.0),
                  'E': (1.0, 1.0, 0.0),
                  '?': (0.5, 0.5, 0.5),
                 }
    input_file = PdfFileReader(open(input_file_name, "rb"))
    output_file = PdfFileWriter()
    cur_page = 0
    input_page = input_file.getPage(cur_page)
    
    for line in lines:
        print(line.label, line.text)
        c = canvas.Canvas('watermark.pdf')
        c.setStrokeColorRGB(*color_dict[line.label])
        c.rect(line.h_left, line.v, line.h_right - line.h_left, 8, stroke=1, fill=0)
        c.save()
    
        watermark = PdfFileReader(open("watermark.pdf", "rb"))    
        
        if line.page_number - 1 == cur_page:
            # new page == old page
            input_page.mergePage(watermark.getPage(0))
        else:
            # перешли на новую страницу
            output_file.addPage(input_page)
            cur_page = line.page_number - 1
            input_page = input_file.getPage(cur_page)
            input_page.mergePage(watermark.getPage(0))
        
    output_file.addPage(input_page)
        
    with open(output_file_name, "wb") as o:
        output_file.write(o)

# %%
draw_rectaingles(data, 'processed/aerospace/y:2015:i:1:p:31-57.pdf')
# Out:
# C
# C Ссылка на статью:
# C // Аэрокосмический научный журнал.
# ? МГТУ им. Н.Э. Баумана. Электрон. журн. 2015.
# E No 01. С. 31–57.
# C DOI: 10.7463/aersp.0115.0775178
# ? Представлена в редакцию: 12.01.2015
# C
# C © МГТУ им. Н.Э. Баумана
# B УДК 543.8 + 541.13
# C Истечение вязкой жидкости через круглые
# C отверстия при малых числах Рейнольдса
# B Пильгунов В. Н.
# C 1,*
# C , Ефремова К. Д.
# C 1
# ?
# B
# A 1МГТУ им. Н.Э. Баумана, Москва, Россия
# ?
# C
# A Рассмотрена  гидродинамика  и  исследован  процесс  истечения  минерального  масла через
# E круглое отверстие диаметром 0,9 мм с острой входной кромкой, расположенное в удлинённой
# E цилиндрической  камере  диаметром  20  мм.  В  процессе  эксперимента  обнаружен  срыв
# E ламинарного  режима истечения  вязкой  жидкости  при  малом  числе  Рейнольдса  Re  =  430,
# E обусловленный  кавитацией  на  острой  кромке  отверстия.  При  числах  Рейнольдса  Re  >  500
# E начинается  интенсивное  пенообразование  в  свободной  струе,  обусловленное  кромочной
# E кавитацией,  и  сопровождаемое  интенсивным  выделением  парогазовых  пузырьков  с  их
# E последующим дроблением при ударе струи о торцевую стенку отводящей камеры. Определено
# E численное  значение  «жизненного»  периода  существования  двухфазной  смеси,  равное  в
# E условиях атмосферного давления окружающего воздуха не менее 30 минут. Установлено, что
# E кавитация в свободной и затопленной струе обусловлена не увеличением скорости в сжатом
# E сечении струи, а особенностями обтекания периферийными струйками острой входной кромки
# E отверстия.  Рассмотрена  электродинамика  процесса  истечения  вязкой  диэлектрической
# E жидкости через отверстие малого диаметра с острой кромкой и подтверждено наличие ранее
# E обнаруженных  авторами  статьи  значительных  по  размаху  высокочастотных  электрических
# E сигналов  сложной  формы.  Результаты  выполненных  исследований  могут  быть  учтены
# E разработчиками дросселирующих элементов гидравлических устройств автоматики.
# A Ключевые слова: истечение жидкости через отверстие малого диаметра, кавитация на острой
# E кромке  отверстия,  электродинамика  процесса  истечения  жидкости  через  отверстие  с  острой
# E кромкой при больших числах Re, пенообразование
# C
# C Введение
# A Значительное число элементов  и  устройств  гидроавтоматики,  системы  подачи
# B топлива  в  тепловых  двигателях,  сварочные  технологии,  технология  производства
# B продуктов питания, процессы и аппараты химического производства и целый ряд других
# B областей техники сталкиваются с необходимостью  учета особенностей истечения вязких
# B жидкостей и газов через круглые и некруглые отверстия и насадки [1].
# A Экспериментальные исследования в этой области знаний обеспечили большой объем
# B информации,  подготовили многочисленные  справочные  материалы  и  рекомендации  по
# B учету  особенностей  движения  жидкости  в  узких  каналах  малой  протяженности.  Эти
# B особенности движения связаны с существенной зависимостью коэффициентов истечения
# B от характера движения жидкости, ее типа и физико-химических свойств.
# A Наиболее существенное влияние на процесс истечения жидкости через отверстия и
# B насадки  оказывает  характер движения  жидкости – будет  ли  он  ламинарным,  или
# B турбулентным, при этом характер напорного движения вязкой жидкости наиболее часто
# B оценивается критерием подобия по Рейнольдсу.
# A Величина числа Рейнольдса (Re) весьма существенно зависит от размеров отверстия,
# B через которое истекает жидкость. Большие значения числа Рейнольдса реализуются даже
# B при небольших  скоростях  истечения  маловязкой  жидкости,  например  воды,  через
# B отверстия средних и больших размеров. Малые числа Рейнольдса могут быть получены
# B только при истечении вязкой жидкости, например минерального масла, через отверстия
# B очень  малых  диаметров  (долей  миллиметра). Например, режим  ламинарного  истечения
# B воды при средней скорости движения 10 м/сек и числе Re = 100 будет реализован, если
# B диаметр  круглого  отверстия составит  0,01мм.  Характер  истечения  жидкости  при  малых
# B числах Re имеет значение в элементах и устройствах гидроавтоматики, обеспечивающих
# B дросселирование вязкого минерального масла через узкие проходные сечения и зазоры.
# A Целью   экспериментального   исследования   является расширенное   изучение
# B особенностей  истечения  минерального  масла – основной  рабочей  жидкости  для
# B гидроприводов – через  круглые  отверстия  малого  диаметра,  уточнение справочных
# B данных  по  коэффициентам  истечения,  а  также  определение  вероятности  появления
# B электрических  процессов  и  светоизлучения,  как  это  было  установлено  в  ранее
# B проведенных исследованиях [2 ... 5].
# C Гидродинамика процесса истечения вязкой жидкости через отверстия
# C малого диаметра
# A Расчетная схема истечения вязкой жидкости (минерального масла) через отверстие
# B малого  диаметра с  острой  входной  кромкой,  установленное  в  цилиндрической  камере
# B большого диаметра, представлена на рис. 1.
# C
# C Рис. 1. Расчётная схема истечения вязкой жидкости через отверстие с острой кромкой.
# C
# A  Подвод А жидкости  в  камеру и  ее  отвод В из  камеры,  а  также  точки  отбора
# B давлений  p1 и p2 расположены  на  достаточно  большом  удалении  от  входной  острой
# B кромки  отверстия,  что  позволяет  рассматривать  потоки  в  соответствующих  сечениях
# B установившимися: L1 =  28d;  L2 =  10d;  L3 =  75d  и  L4 =  40d,  где  d =  0,9  мм – диаметр
# B отверстия с острой кромкой.
# C А. Свободная струя
# A Истечение  жидкости  через  отверстие  в  газовую  среду  в  режиме  свободной  струи
# B происходит в случае, если пропускная способность отвода В значительно больше расхода
# B струи,  а  выпускная  камера  соединена  с  атмосферой  посредством  крана К (нижняя
# B половина рис.1).
# A Уравнение Бернулли, записанное для сечений 1 – 2 в избыточной системе единиц
# B измерения давления, имеет вид
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C  , (1)
# B где  – плотность однофазной жидкости;
# E V1 – осредненная  скорость  движения  жидкости  в  подводящем  канале  диаметром
# B D = 22d;
# C Vсж – осредненная скорость движения жидкости в сжатом сечении струи;
# C V – осредненная скорость движения жидкости во входном сечении отверстия;
# E   ,    – коэффициенты  неравномерности  течения  жидкости  соответственно  в
# B сечениях 1 и 2;
# E  отв – коэффициент  гидравлического  сопротивления  круглого  отверстия  с  острой
# B кромкой.
# A Примечание. В уравнении  (1)  и  далее  в  размерности  всех  физических  величин
# B представлены в системе СИ.
# A Если истечение  жидкости  происходит  с  большим расходом,  то наблюдается
# B кавитация  жидкости  на  острой  кромке  отверстия. Назовем  ее  условно кромочной
# B кавитацией [2]. В  жидкости  в  этом  случае  выделяются  паровоздушные  пузырьки,  а
# B содержимое  струи  будет  представлять  собой  двухфазную  смесь  с  плотностью см.
# B Выражая  в  уравнении  (1)  скорости  движения  через  массовый  расход  G и принимая
# B ламинарным течение жидкости в подводящей камере ( 2 = 2), получим
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C    , (2)
# C
# B где А – площадь проходного сечения подводящего канала диаметром D;
# ? Аотв – площадь проходного сечения отверстия диаметром d по входной кромке;
# E  = Асж/Аотв – соотношение площадей сжатого сечения струи и отверстия, известный
# B в литературе как коэффициент сжатия струи [2].
# A Преобразуем  уравнение  (2),  приведя  площади  проходных  сечений  к  площади
# B проходного сечения отверстия:
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C  . (3)
# A Здесь m = А/Аотв – соотношение площадей проходных сечений подводящего канала
# B и отверстия.
# A Из  уравнения  (3)  установим  связь  между  массовым  расходом  G  и  давлением p1 в
# B сечении подводящей камеры (давлением истечения):
# C
# C
# C
# C  , (4)
# B где –    коэффициент массового расхода свободной струи, определяемый выражением
# B
# C
# C
# C
# C
# C
# C
# C
# C
# C
# E  . (5)
# A Если  жидкость  истекает  через  отверстие  с  острой  кромкой  в бескавитационном
# B режиме (без  выделения парогазовых  пузырьков),  то  смесь  имеет  плотность  однофазной
# B жидкости  см =  и коэффициент массового расхода (5) примет вид
# C
# C
# C
# C
# C
# C
# E  . (6)
# C Б. Затопленная струя
# A Жидкость истекает через отверстие в режиме затопленной струи, если пропускная
# B способность  отвода В меньше  расхода  струи,  а  выходная  камера  изолирована  от
# B атмосферы (верхняя половина рис. 1). В этом случае уравнение Бернулли, записанное для
# B сечений 1 – 2 в избыточной системе единиц измерения давления, имеет вид
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# E             , (7)
# B где v2 = vк – осредненная  скорость  движения  жидкости  в  сечениях  подводящего  и
# B отводящего каналов камеры;
# E  р  1 – коэффициент  гидравлических  потерь  при  расширении  потока  в  формуле
# B Борда.
# A Выражая, как и прежде, скорости в уравнении (7) через массовый расход G, получим
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C  . (8)
# A В этом случае массовый расход G будет связан с перепадом давлений p = p1  p2 на
# B отверстии выражением
# C
# C
# C
# C  , (9)
# B где    – коэффициент массового расхода затопленной струи, соответствующий равенству
# B
# C
# C
# C
# C
# C
# C
# C
# E   . (10)
# B Экспериментальное исследование процесса истечения вязкой жидкости
# C через круглое отверстие малого диаметра
# A Для  экспериментального  исследования процесса  истечения  вязкой  жидкости  через
# B круглое отверстие малого диаметра с острой кромкой был изготовлен прозрачный модуль,
# B представленный на фото рис. 2.
# C
# C
# B Рис. 2. Модуль для исследования процесса истечения жидкости через круглое отверстие малого диаметра с
# E острой кромкой.
# C
# A В прозрачном корпусе 1 из органического стекла выполнен канал диаметром D = 20
# B мм, в который встроена стальная шайба 2 с  круглым отверстием диаметром d = 0,9 мм.
# B Для  исследования  электрических  процессов  в  потоке  минерального  масла  вдоль  оси
# B канала  натянута струна  3, выполненная  из нихромовой эмалированной проволоки
# B диаметром dпр = 0,22 мм. Струна проходит через уплотнения в корпусе модуля. На струне
# B выполнена метка в виде зачистки эмалевой изоляции шириной
# E  = 0,1 мм, которая может протягиваться вдоль оси канала посредством натяжителя 4
# B с  транспортиром.  Подвод  минерального  масла  к  камере  производится  через
# B быстроразъемное соединение p0.
# A Для  формирования  свободной  струи  отвод  жидкости  из  камеры  модуля
# B обеспечивается  через  дренажное  быстроразъёмное  соединение  L  при  открытом  в
# B атмосферу сливе Т (рис.2).
# A Затопленная  струя  образуется,  когда  отвод  жидкости  из  камеры  происходит  через
# B слив Т при закрытом дренаже L.
# A Общий вид экспериментального стенда показан на фото рис. 3.
# C
# C
# C Рис. 3. Общий вид экспериментального стенда.
# C
# A Питающая  установка  состоит  из  нерегулируемого  объемного  насоса  с  рабочей
# B подачей Qн = 4 л/мин, снабженного переливным клапаном 1. Тонкая настройка давления
# B питания  модуля при  малых  числах  Рейнольдса Re  400 обеспечивается  регулируемым
# B дросселем  2,  включенным  в  линию байпаса  насоса,  и  регулируемым  дросселем  4,
# B установленным на входе в модуль 5. Управление подачей минерального масла в модуль
# B осуществляется  гидравлическим  распределителем  3.  Для  измерения  массового  и
# B объемного расходов минерального масла использовались мерный цилиндр 6, электронные
# B весы  и  частотомер – хронометр.  Уровни  давлений  p1 и  p2 в  подводящей  и  отводящей
# B камерах модуля регистрировались образцовыми манометрами. Координаты расположения
# B точек отбора давлений представлены на расчетной схеме рис. 1.
# A Исследование процесса истечения вязкой жидкости через круглое отверстие малого
# B диаметра  проводилось  на  минеральных  маслах  МГЕ10  и  «Shell  Tellus–20»  с
# B кинематической  вязкостью 25 =  30  сСт.  На  графиках  рис.  4  представлены
# B экспериментально  полученные  значения  коэффициентов массового м и  объемного об
# B расходов, где об = м/, для свободной и затопленной струй.
# C
# C Рис. 4. Зависимость коэффициентов расхода м и об от числа Рейнольдса.
# C
# A Значения  числа  Рейнольдса  определялись  через  скорость  истечения  идеальной
# B жидкости, определяемой по формуле Торичелли
# C
# C
# C
# E  . (11)
# A В  процессе  эксперимента  был  обнаружен  срыв  режима  ламинарного  процесса
# B истечения при Re  430, обусловленный началом кавитации на острой кромке отверстия.
# B При   дальнейшем   увеличении   скорости   истечения   начинается   интенсивное
# B пенообразование,  причиной  которого  можно  считать процесс  кавитации  с  интенсивным
# B выделением парогазовых пузырьков и их последующим дроблением при ударе свободной
# B струи о торцевую стенку отводящей камеры.
# A На рис. 5. представлены фото свободной ламинарной (рис. 5а) и турбулентной струи
# B (рис. 5б).
# A Покадровое  фотографирование  развития  процесса  пенообразования  в  короткой
# B отводящей  камере  (L4 =  40d,  рис.1)  показало,  что  после  начала  образования  пены
# B дальнейшее  повышение  давления  истечения  p1 при  недостаточной  пропускной
# B способности  дренажа  L  приводит  к  интенсивному  развитию  «пенного  кокона»,
# B обволакивающего свободную струю и вызывающего, впоследствии, ее затопление (рис.
# B 6).
# C
# C
# E а) свободная ламинарная струя;
# C
# E б) свободная турбулентная струя.
# C Рис. 5. Фото ламинарной и турбулентной струи в отводящей камере.
# C
# C
# ?
# C Рис.6. Турбулентная свободная струя в «пенном коконе».
# C
# A На  графике  3  рис.  4  видно,  что  после  срыва  ламинарного  характера истечения
# B свободной  струи,  увеличение  размеров  «пенного  кокона»  приводит  к  полному
# B обволакиванию  струи  и  ее  затоплению.  Это,  в  свою  очередь, приводит  к  частичному
# B выравниванию значений коэффициентов объемного расхода об для свободной и условно
# B затопленной струй.
# A На  фото  рис.  7  показан «жизненный»  период двухфазной  смеси:  естественная
# B флотация  пузырьков  отсутствует  (рис.7а),  растворение  пузырьков  начинается  в  донной
# B части  мерного  цилиндра  (рис.7б),  где  весовое  давление  наибольшее.  Через  30  минут
# B (рис.7в)  весь  выделившийся  воздух  переходит  в  растворенное  состояние, а  пары
# B минерального масла конденсируются.
# C
# E а) исходное состояние двухфазной смеси;
# C
# C
# E б) растворение воздушных пузырьков в донной части мерного цилиндра через 10 минут после заполнения
# E сосуда смесью;
# C
# E в) полное растворение воздушных пузырьков через 30 минут после заполнения сосуда смесью.
# C Рис.7. «Жизненный» период двухфазной смеси.
# C
# A При  высокой  скорости  движения  струи,  увеличение  длины  отводящего  канала  до
# B значения L4 = 240 мм, путем установки дополнительного круглого патрубка не уменьшило
# B интенсивность дробления  струи  при  ее  ударе  о  торцевую  стенку  отводящей  камеры  и
# B пенообразование сохранилось.
# A Процесс  пенообразования  стал  более  интенсивным,  когда  при  закрытом  сливе  Т
# B (рис. 2) отводящая камера соединялась с атмосферой только через дренаж L.
# A Пена  представляет  собой  двухфазную  систему,  в  которой  газ,  являющийся
# B диспергированной  фазой,  составляет  достаточно  большую  часть  объема  системы.  В
# B работе [7] отмечено, что «углеводороды каждого класса, присутствующие в минеральном
# B масле,  мало  склонны  к  образование пен, но  уже  смеси  этих  углеводородов  способны  к
# B вспениванию...», при этом чем выше вязкость, тем более стабильные пены они образуют.
# B Стабильность  пены  зависит  от  прочности  поверхностных  пленок,  образуемых  вязкими
# B маслами вокруг мельчайших пузырьков воздуха. При этом, к усилению пенообразования и
# B повышению  стабильности  пены  приводит наличие  в  минеральном  масле  поверхностно-
# B активных  веществ,  к  которым  можно  отнести  антикоррозионные,  противоизносные  и
# B моющие присадки.
# A Пенообразование  определяется  условиями,  которые  могут  возникнуть  при
# B энергичном  перемешивании  минерального  масла  с  воздухом,  когда  растворенный  и
# B взвешенный  в  жидкости  воздух,  а  также  низкокипящие  фракции  многокомпонентной
# B смеси  выделяются  из  жидкости.  Если  предположить,  что  объем  газа,  находящийся  в
# B ограниченном  объеме  двухфазной  смеси  (минерального  масла  с  нерастворенным
# B воздухом),  полностью  перейдет  в  растворенное  и  мелкодисперсное  нерастворенное
# B состояние, то можно оценить процент газосодержания жидкости в ее исходном состоянии
# B при атмосферном давлении, путем анализа соотношения объемов:
# C
# C
# E         . (12)
# A Здесь Wсм – первоначальный  объем  смеси,  измеряемый  в  течение  10  сек  после
# B наполнения  мерного  цилиндра; W – объем  минерального  масла  после  полного
# B растворения  мелкодисперсных  пузырьков  воздуха и  конденсации  паров  (определяется
# B через 30 минут после замера первоначального объема двухфазной смеси).
# A Результаты анализа показали, что при величине давления истечения p1  1800 кПа
# B можно принять Г = 6% = 0,06, а при p1  2000  кПа, Г = 7,5% = 0,075. Таким образом,
# B объем  минерального  масла  W  после полного  растворения  мелкодисперсных  воздушных
# B пузырьков  и  конденсации  паров  можно  оперативно  и с  малыми  затратами  времени
# B определять через первоначальный объем смеси Wсм с учетом соотношения
# C
# C
# C
# E  . (13)
# A В  соответствии  с  законом  сохранения  массы,  плотность  двухфазной  смеси см
# B связана с объемом минерального масла W, его плотностью , объемом двухфазной смеси
# B Wсм и ее плотностью см, а также с объемом выделившегося из жидкости воздуха Wвозд и
# B его плотностью  возд соотношением
# C                        ,
# B или с учетом равенства (13) – соотношением
# B
# C
# C
# E  . (14)
# A Измеренная  исходная  плотность  минерального  масла  при  температуре  t  =  240С
# B составила  = 845 кг/м3 . Если принять плотность воздуха при атмосферном давлении pатм
# B = 745 мм рт.ст.,  возд = 1,3 кг/м3, то для значения Г = 0,06 плотность двухфазной смеси в
# B соответствии с равенством (14) составит см = 800 кг/м3. Измеренная весовым способом
# B плотность  двухфазной  смеси  дала значение см =  805  кг/м3.  Таким  образом,
# B экспериментальное и рассчитанное значение плотности через величину газосодержания Г
# B получились близкими.
# A Приведенные  на  рис.  4  графики  зависимости  коэффициентов  расхода  от  числа
# B Рейнольдса  получены  на  минеральном  масле  МГЕ10.  Замена  этого  масла  минеральным
# B маслом  «Shell-Tellus  20»  дала  такие  же  значения,  однако  кавитация  и  процесс
# B пенообразования  начались  при  значении  числа  Рейнольдса  Re  =  1000,  что  в  2,5  раза
# B превысило  значение  Re  при  аналогичных  испытаниях  минерального  масла  МГЕ10.
# B Интенсивность  пенообразования  и  стабильность  пены  остались  при  этом  практически
# B неизменными.
# A В процессе обработки экспериментальных данных были построены графики (рис. 8)
# B соотношения осредненной скорости движения жидкости во входном сечении отверстия,
# B которую можно представить как пропускную способность отверстия
# C
# C
# C
# C
# C
# C
# E  , (15)
# B и осредненной скорости струи в сжатом сечении
# B
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# E  , (16)
# C
# B где  = об/ – коэффициент скорости.
# A Для  оценки  значения  коэффициента  объемного  расхода графическим  путем,
# B представлена  величина  скорости  истечения  идеальной  жидкости,  определяемая  по
# B формуле  (11).  При  подсчете  значений  скорости  жидкости  в  сжатом  сечении  струи  Vсж
# B была  использована  зависимость  коэффициента  сжатия  струи  от  числа Рейнольдса  = 
# B (Re), приведенная в работе [8].
# C
# ? Рис.8. Значения скоростей движения жидкости в сечениях потока при истечении жидкости через круглое
# E отверстие.
# C
# A В соответствии с равенством (15) имеем
# C
# C
# C
# C
# C
# C
# C
# C
# C  .
# A Таким  образом,  коэффициент  объемного  расхода об можно  рассматривать  как
# B отношение отрезков oc/oa (рис. 8), или как безразмерную осредненную скорость жидкости
# B в  сечении отверстия  по  острой  кромке,  отнесенную  к  скорости  истечения  идеальной
# B жидкости,  а  коэффициент  скорости  - как  отношение  отрезков ob/oa или  как
# B безразмерную  осредненную  скорость  жидкости  в  сжатом сечении  струи,  отнесенную  к
# B скорости истечения идеальной жидкости.
# A В   качестве  примера  воспользуемся  графиками  рис.  8  для  определения
# B коэффициентов истечения затопленной струи:
# E – для Vид =  22 м/сек, что соответствует числу Re =  600, соотношения отрезков дают
# B об = 0,634 и  = 0,77;
# E – в соответствии с графиком рис. 4, при том же значении Re = 600, имеем об = 0,64.
# A Экспериментально полученное значение коэффициента скорости  = 0,77 несколько
# B меньше величины, приведенной в работе [7] величины  = 0,81.
# A Принимая нижеследующие исходные данные
# C Re = 400;  = 845 кг/м3; см = 800 кг/м3; m = 22,2; m2 = 494;   = 0,06;  = 0,80,
# B оценим адекватность зависимости (5) для свободной турбулентной струи с интенсивным
# B пенообразованием.
# A Рассчитанное по  формуле  (5)  значение  коэффициента  массового  расхода м =  620
# B близко к экспериментальному значению м = 580, полученному из графика рис. 4 для Re =
# B 400.
# A Используя  формулу (10), определим значение коэффициента массового расхода м
# B для затопленной струи, добавив к исходным данным значение коэффициента расширения
# B потока  в  формуле  Борда  р =  1:  полученное  расчетное  значение м =  630 близко  к
# B экспериментальному  значению м =   620 для  свободной  струи,  что подтверждает
# B равенство параметров истечения через круглое отверстие с острой кромкой для свободной
# B и затопленной струй.
# A Установим возможную  причину  кавитации  жидкости  [9]  в  затопленной  струе,  для
# B чего  запишем  систему  уравнений  Бернулли  для  сечений  1 – 3  и  3 – 2  (рис.  1), причем
# B сечение 3 соответствует сжатому сечению струи на расстоянии L = (2...3)d от плоскости
# B входной кромки отверстия, тогда получим
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# E   (17)
# B где,  как и прежде, V1 = V2; Vсж и V – соответственно осредненные скорости движения
# B жидкости  в  подводящем  и  отводящем  каналах,  в  сжатом  сечении  струи  и  во  входном
# B сечении отверстия.
# A Вычтем  второе  уравнение  системы  (17)  из  первого  и  запишем уравнение (18)
# B относительно давления p3 в сжатом сечении струи. Принимая  1 =  2 =  2 (ламинарный
# B поток  в  подводящем  и  отводящем  каналах)  и  3 =  1 (турбулентная  струя), выражаем
# B скорости через массовый расход G и получаем
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# E   . (18)
# A В  соответствии  с  экспериментальными  данными,  кавитация  в затопленной струе
# B начинается при следующих значениях, входящих в уравнение (18) величин:
# C p1 = 590 кПа; p2 = 98,1 кПа; G = 0,0114 кг/сек; Re 1022 и  = 0,82.
# A Принимая значение площади отверстия Аотв = 0,636 мм2; m = 22,2;  отв = 0,06;  р = 1;
# B  = 845 кг/м3 и см = 800 кг/м3, получим в соответствии с уравнением (18), p3 = 203 кПа.
# A Таким образом, в сжатом сечении устанавливается избыточное давление, и вынос в
# B струю  кавитационных  паровоздушных  пузырьков  определяется  только  особенностями
# B процесса огибания периферийными струйками острой входной кромки отверстия.
# A Свободная струя  вытекает  в  отводящий  канал  с  атмосферным  давлением,
# B следовательно,  и  в  этом  случае  причиной  кавитации  является  процесс огибания
# B периферийными струйками острой входной кромки отверстия.
# A В  работе  [2]  приводится  одна  из  версий  зарождения кавитационного  тора при
# B огибании периферийными  струйками  условно  острой  входной кромки  диафрагменного
# B дросселя.  Если  предположить  равномерность  движения  жидкой  частицы  на  участке
# B огибания периферийной  струйкой  острой  входной  кромки  отверстия  по  криволинейной
# B траектории  с  постоянным  радиусом r,  такое  движение  можно  рассматривать  как
# B равноускоренное, c нулевым локальным ускорением V/t =  0 и конечными значениями
# B конвективных  ускорений V/S  0, обусловленных  изменением  направления  вектора
# B скорости (рис. 9).
# C
# C
# C Рис. 9. Схема огибания периферийной струйкой острой входной кромки.
# C
# A В  этом  случае   ускорение  направлено  к  центру  окружности  радиуса r
# B перпендикулярно    вектору    скорости    и    рассматривается    как    нормальное
# B центростремительное ускорение переносного движения
# C
# C
# C
# E  . (19)
# A На  частицу  жидкости  массой m,  расположенную  на  периферийной  струйке  и
# B огибающую  острую  кромку,  в  центре  ее  массы  действует  центробежная  сила    ,
# B направленная от центра окружности
# C
# C
# C
# E  . (20)
# A Удерживает   частицу   на   траектории   ее   движения   уравновешивающая
# B центростремительная сила Fцс, определяемая силами давления со стороны соседствующих
# B с ней частиц с внешней стороны траектории (подпирающее усилие), и силами растяжения
# B со  стороны  частиц  с  внутренней  стороны  траектории,  прилипших  к  твердой  стенке
# B (притягивающее  усилие).  Можно  предположить,  что  при  несмачиваемости стенки
# B жидкостью, притягивающее усилие будет отсутствовать.
# A Объем  частицы  капельной  жидкости  сферической  формы  радиусом R связан  с  ее
# B массой и плотностью равенством
# C
# C
# C
# C
# C
# C
# E      . (21)
# A В этом случае радиус R определяется выражением
# C
# C
# C
# C
# C
# C
# C
# C
# C
# C
# E  . (22)
# A Если предположить равенство по модулю подпирающего и притягивающего усилий,
# B то результирующая поверхностная сила, действующая на плоское диаметральное сечение
# B сферы площадью
# C
# C
# C
# C
# C
# E  , (23)
# B будет определяться равенством
# B
# C
# C
# C
# C
# C
# C
# C
# E  . (24)
# A Выражая  из  уравнения  (24)  величину  давления p,  которая  в  механике  жидкости
# B рассматривается как интенсивность поверхностной силы, получим
# C
# C
# C
# C
# C
# C
# E  . (25)
# A Подстановка в уравнение (25) среднего значения плотности минерального масла  =
# B 845 кг/м3 определяет  выражение  для  численной  оценки  интенсивности  поверхностной
# B силы
# C
# C
# C
# E  . (26)
# A В  выражении  (26)  величина  массы m не  определена,  поэтому  целесообразно
# B оценивать интенсивность поверхностной силы, приведенной к массе     :
# C
# C
# C
# C
# C
# C
# E  . (27)
# A В табл.1 представлены величины интенсивности приведенной поверхностной силы,
# B подсчитанные в соответствии с равенством (27) для конкретных значений r и V.
# C Таблица 1. Интенсивность приведенной поверхностной силы.
# C r = 1 мм r = 0,5 мм r = 0,1 мм
# C V, м/с p/m0,33, м/с2 V, м/с p/m0,33, м/с2 V, м/с p/m0,33, м/с2
# C 0,5 9103 0,5 18103 0,5 90103
# C 1 3,7104 1 7,4103 1 37103
# C 2 1,48105 2 2,96105 2 14,8105
# C 5 9,25105 5 18,5105 5 92,5105
# C 10 3,7106 10 7,40106 10 37106
# C 50 9,25107 50 18,5107 50 92,5107
# C
# A Данные табл. 1 показывают, что на частицу минерального масла, расположенную на
# B периферийной  струйке  и  огибающую  острую  входную  кромку отверстия,  может
# B действовать достаточно большое по величине растягивающее усилие, которое может стать
# B причиной, вызывающей кромочную кавитацию.
# A В  соответствии  с  равенством  (27)  и  табл.1,  величина  растягивающего  усилия
# B существенно зависит от остроты входной кромки, определяющей степень сжатия струи и
# B радиус  кривизны траектории. Например, уменьшение радиуса притупления кромки от 1
# B мм до 0,05 мм увеличивает интенсивность приведенной поверхностной силы в 20 раз.
# A Количественная  оценка  интенсивности растягивающего  усилия  дала  следующие
# B результаты:
# E 1) R =  0,1 мм; W =  4,210-12 м3;  =  860 кг/м3; m =  0,3610-8 кг; m0,33 =  0,0016
# B кг0,33/м. Для r = 1 мм и V = 50 м/c: p = 152 кПа; для r = 0,5 мм и V =50 м/с: p = 304 кПа.
# E 2) R = 0,05 мм; W = 0,5210-12 м3;  = 860 кг/м3; m = 0,04510-8 кг;m0,33 = 0,00079
# B кг0,33/м. Для r = 1мм и V = 50 м/c: p = 75 кПа; для r = 0,5 мм и V =50 м/с: p = 150 кПа.
# A Как  было  отмечено  выше,  для  исследования  электрических  процессов  в
# B кавитирующем потоке минерального масла, вдоль оси прозрачного модуля была натянута
# B струна  из  эмалированной  проволоки  диаметром dстр = 0,22 мм  с  точечной  зачисткой
# B эмалевой изоляции для формирования метки.
# A Струна  и  шайба  образуют  кольцевое  отверстие,  истекая  через  которое  струя
# B подвергается одностороннему сжатию, поскольку со стороны струны жидкость граничит
# B с  цилиндрической  поверхностью  струны,  а  с  другой  стороны огибает острую  кромку
# B круглого  отверстия  диаметром d = 0,9 мм.  В  этом  случае  площадь  проходного  сечения
# B отверстия будет определяться равенством
# A  А отв = 0,785 (d2  d 2стр) , (28)
# B а  площадь  сжатого  сечения  струи  будет  учитывать  соотношение  площадей  сжатого
# B сечения струи и отверстия :
# B  A сж = 0,785 (d2  d 2стр). (29)
# A Необходимо  напомнить,  что  коэффициент  сжатия  струи  является  функцией  числа
# B Рейнольдса  =  (Re) [8]. Подсчитанные  значения  Асж и  для  кольцевого  отверстия
# B представлены в табл. 2.
# C Таблица 2. Параметры сжатия струи в кольцевом отверстии.
# C Re 100 200 300 400 500 600 700 800 900
# C  0,95 0,91 0,895 0,88 0,865 0,85 0,84 0,83 0,82
# C А сж, мм2  0,566 0,541 0,531 0,521 0,512 0,502 0,496 0,489 0,483
# C
# A Экспериментально  полученные  графики  зависимости  коэффициентов  массового  и
# B объемного  расходов  минерального масла  фирмы  «Shell-Tellus 20»  от  числа Re
# B представлены на рис. 10.
# C
# C Рис. 10. Зависимость коэффициентов расхода от числа Рейнольдса.
# C
# A Сравнительный анализ графиков рис. 10 и рис. 4 показывает, что срыв ламинарного
# B характера  истечения  жидкости  через круглое  отверстие  и  через  кольцевое  отверстия  с
# B односторонним поджимом струи наступает при равных числах Re = 450500.
# A До срыва ламинарного характера истечения коэффициенты объемного и массового
# B расхода свободной струи, истекающей через круглое отверстие, существенно превышают
# B аналогичные коэффициент расхода кольцевого отверстия ( об = 0,67; об = 0,59 и м = 570;
# B  м = 520 соответственно).
# A После  срыва  характера  истечения  при Re  Reкр уменьшение  коэффициента
# B объемного  расхода  свободной  струи,  истекающей через  кольцевое  отверстие,  весьма
# B существенно  и  принимает  значение  об =   0,25,  по  сравнению  с  уменьшением
# B коэффициента объемного расхода круглого отверстия  об = 0,52.
# A Логично предположить, что такие несоответствия значений коэффициентов расхода
# B могут быть связаны с различием физико-химических свойств минеральных масел МГЕ-10
# B и «Shell- Tellus 20».
# A Графики  соотношения  осредненной  скорости  движения  жидкости  во  входном
# B сечении  кольцевого  отверстия V = Q/Aотв, осредненной  скорости  струи  в  ее  сжатом
# B сечении V сж = Q/Aсж и  скорости  истечения  идеальной  жидкости,  рассчитанной  по
# B формуле (11), представлены на рис. 11.
# A Скорости истечения идеальной жидкости Vид =  22 м/сек соответствует  критическое
# B значение  числа Re кр =  500.  Полученные  путем  анализа  отрезков  из  графиков  рис.11,
# B значения  коэффициента  объемного  расхода об = V/Vид ,  полностью  соответствуют
# B значениям об, полученным из графика рис.10.
# C
# ? Рис. 11. Значения скоростей движения жидкости в сечениях потока при истечении жидкости через
# E кольцевое отверстие.
# C Электродинамика истечения вязкой жидкости через отверстие малого
# C диаметра
# A В работах [2 ... 5] отмечается, что процесс движения диэлектрической жидкости в
# B узких  каналах  дросселирующих  устройств  сопровождается  значительными  по  размаху
# B высокочастотными электрическими сигналами сложной формы.
# A В настоящей работе в целях исследования этих электрических процессов вдоль оси
# B потока  в  прозрачном  модуле  было  натянута  струна  из нихромовой эмалированной
# B проволоки с выполненной на ней меткой, путем зачистки эмалевой изоляции шириной
# E  = 0,1 мм (рис. 2). Протяжка метки вдоль оси потока с фиксацией координаты метки
# B с  погрешностью  не  выше  0,1  мм  позволила  зондировать  электрический  потенциал  в
# B выбранном  сечении  потока.  Для  анализа  формы,  частоты  и  размаха  электрических
# B сигналов использовались  электронно-лучевой  осциллограф  С1-83  и  анализатор  спектра
# B Я40-0830.
# A В  исследованиях  [2,  3]  показано  наличие  в кавитирующем потоке  минерального
# B масла  интенсивного  светоизлучения  в  голубой  части  спектра.  При  истечении  жидкости
# B через  круглое  отверстие  малого  диаметра,  выполненное  в  стальное  пластине,
# B светоизлучение на острой кромке не наблюдалось.
# A Одной  из  возможных  причин  отсутствия  светоизлучения  при  наличии  активных
# B электрических  процессов  в  сжатом  сечении  струи  можно  считать  интенсивное
# B пенообразование, изменившее условия, приводящие к светоизлучению.
# A В  упомянутых  выше  работах  [2...5]  диафрагменный  дроссель  с  условно  острой
# B кромкой  (900)  был  выполнен  из  диэлектрика,  поэтому  на кромке мог  накапливаться
# B электрический потенциал, который инициировал светоизлучение.
# A На  металлической  шайбе  электрический  потенциал  может  быть  рассредоточен  в
# B объеме  металла.  Однако,  это  только  предположения – вполне  вероятно,  что  при  более
# B высоких скоростях движения жидкости через отверстие и, соответственно, при большей
# B плотности заряда на острие кромки, светоизлучение возникнет.
# A Спектральная характеристика электрических сигналов в одном из сечений модуля в
# B режиме затопленной струи, наблюдаемая на экране анализатора спектра, представлена на
# B фотографии рис. 12.
# C
# C Рис. 12. Спектральная характеристика электрического сигнала.
# C
# A Частотный спектр электрических сигналов лежит в диапазоне Df = 1,5 ... 12 кГц. На
# B величину  размаха  электрического  сигнала  и  его  частотный  спектр  существенно  влияет
# B осредненная  скорость  движения жидкости  в  сечении  потока  и  ее  физико-химические
# B свойства, в частности, коррегирующие присадки.
# A На  фото  рис.  13  представлена  форма  электрических  сигналов  в  сечениях
# B прозрачного модуля (номера сечений соответствуют рис. 1) .
# C
# E а) исходный фон электрического сигнала;
# C
# E б) электрический сигнал в сечении No1;
# C
# E в) электрический сигнал в сечении по острой кромке;
# C
# E г) электрический сигнал в сечении No2.
# C Рис. 12. Формы электрических сигналов в сечениях прозрачного модуля.
# C
# A Численные  результаты  осциллографирования электрических  сигналов  в  сечениях
# B турбулентного потока представлены на сводной диаграмме рис. 13.
# C
# C Рис. 13 Сводная диаграмма размаха электрических сигналов в сечениях потока.
# C
# A Местонахождение  метки  в  сечении  потока  определяется  осью  «мм».  Размах
# B электрического сигнала в заданном сечении при перепадах давлений p = 0,5 МПа и p =
# B 2,0 МПа показан на осях «мВ».
# A Наибольший  размах  сигнала  обнаружен  в  сечении  по  острой  входной  кромке
# B отверстия,  где  образуется кавитационный  тор [2]  и  зарождаются  каверны.  Наличие
# B электрических  сигналов  в  ламинарных  потоках  подводящего  и  отводящего  каналов
# B обнаружено  также  и  в  работе  [1],  что  может  быть  обусловлено  электризацией
# B диэлектрической  жидкости  при  ее  движении  по  пластиковому  рукаву  от  питающей
# B установки, несмотря на то, что быстроразъемные соединения p0 и Т были заземлены (рис.
# B 2).
# A Электрокинетические  свойства  потока  минерального  масла  в  узких  каналах  и
# B рабочая версия природы, наблюдаемых электрических процессов, подробно изложены в
# B работах [4,5]. Суть происходящего в рассматриваемом случае заключается в следующем.
# A При  движении  вязкой  диэлектрической  жидкости  с  большой  скоростью  в  узких
# B каналах,  при  ее  огибании  острой  кромки,  образуется  двойной  электрический  слой,
# B обусловленный  двумя   физико-химическими  механизмами – ориентационным и
# B примесным.
# A При  ориентационном  механизме  молекулы  жидкости,  имеющие  ненулевой
# B дипольный  момент,  располагаются  на  поверхности  раздела  твердой  и  жидкой  сред,
# B преимущественно  одним  концом  в  сторону  жидкой  фазы.  Одновременно,  при  наличии
# B кавитации на  острой  входной  кромке  отверстия,  образуется  двухфазная  среда
# B «нерастворенный воздух (с парами жидкости) – жидкость».
# A Примесный механизм обусловлен тем, что некоторые ионы примеси адсорбируются
# B преимущественно вблизи поверхностей раздела двух сред «твердая стенка – жидкость» и
# B «жидкость – газовая фаза».
# A На острой входной кромке отверстия в результате кавитации образуется постоянно
# B обновляющийся  тонкий  слой  паро-воздушных  микропузырьков,  локализованных  на
# B острие  кромки.  До  момента  наступления кавитационного разрыва  сплошности  жидкой
# B среды были зарегистрированы электрические сигналы сравнительно небольшого размаха.
# B Увеличение  скорости  потока  на  острой  кромке  вызвало  возрастание  амплитуды
# B электрического  сигнала  и  увеличение  их  частоты.  Под  влиянием  потока  в движение
# B относительно  поверхности  раздела  вовлекается  не  весь  двойной  ионный  слой,  а  лишь
# B некоторая его небольшая часть с координатой X  Xс, причем Xс  dо (здесь Xс – граница
# B скольжения; dо – кинетический диаметр молекулы жидкости).
# A При  условии X  Xс заряды  могут  перемещаться  только  вместе  с  поверхностным
# B слоем: именно они и образуют на поверхности раздела  «жидкость – твердая стенка» (в
# B данном   случае   на   острой   кромке)   после   «смывания»   диффузного   слоя
# B нескомпенсированный электрический заряд, уносимый потоком жидкости. Электрический
# B потенциал  в  сечении  жидкости  на  расстоянии Xс от  поверхности  обычно называют   -
# B потенциалом,  величина  которого  мало  зависит  от  материала  твердой  стенки,  но  очень
# B сильно  зависит  от  физико-химических  свойств  диэлектрической жидкости.  Ослабление
# B потенциала по мере  удаления сечения потока от плоскости острой  кромки  обусловлено
# B размыванием этих электрических зарядов в расширяющемся потоке жидкости.
# C Основные выводы по результатам исследования
# E 1) Получены  значения  коэффициентов  массового  и  объемного  расходов  вязкой
# E многокомпонентной  жидкости  (минерального  масла)  при  ее  истечении  через
# E отверстия круглой формы при малых (до 100) значениях числа Рейнольдса.
# E 2) Установлено  наличие  интенсивных кавитационных процессов  на  острой  кромке
# E отверстия (кромочная кавитация) с активным пенообразованием и выносом пены
# E на большое удаление от зоны кавитации.
# E 3) Обнаружен срыв режима процесса истечения жидкости через отверстие с острой
# E кромкой в газовую среду  с атмосферным давлением, в форме свободной струи и
# E превращение ламинарной  струи  в  турбулентную с  интенсивным  образованием
# E вихревых шнуров.
# E 4) Значение коэффициента объёмного расхода круглого отверстия  с острой кромкой
# E несколько  превышает  значение  коэффициента  расхода  кольцевого  отверстия  с
# E односторонним сжатием струи: уменьшение коэффициента объемного расхода при
# E срыве режима истечения через кольцевое отверстие более существенно.
# E 5) «Жизненный» период  двухфазной  среды   «жидкость – мелкодисперсный
# E нерастворенный  воздух»  после  интенсивного  пенообразования  достаточно
# E длителен и составляет при атмосферном давлении не менее 30 минут.
# E 6) Объемное газосодержание двухфазной смеси после интенсивного пенообразования
# E может достигать величины Г = 8%.
# C 7) При этом практически весь объем мелкодисперсного нерастворенного воздуха
# C 8) переходит в растворенное состояние и не выделяется в атмосферу.
# E 9) Интенсивность   пенообразования   существенно   возрастает   при   дроблении
# E пузырьков кавитирующей струи о стенку-преграду.
# E 10) Подтверждено  наличие  высокочастотных  электрических  процессов  сложной
# E формы и большой интенсивности при истечении диэлектрической жидкости через
# E отверстие с острой кромкой в условиях кромочной кавитации.
# E 11) Светоизлучение в сечении острой кромки стальной шайбы в условиях проведенных
# E экспериментов не обнаружено.
# E 12) Результаты  проведенных  исследований  могут  быть  учтены  разработчиками  при
# E проектировании   дросселирующих   элементов   гидравлических   устройств
# E автоматики.
# C Список  литературы
# E 1. Пильгунов  В.Н.,  Ефремова  К.Д.  Особенности истечения  жидкостей  через  отверстия
# E некруглой  формы // Наука и образование. МГТУ им. Н.Э. Баумана. Электрон. журн.
# E 2015. No 2. С. 1-23. DOI: 10.7463/0215.0758817
# E 2. Пильгунов  В.Н.,  Ефремова  К.Д.  Светоизлучение  и  электрические  процессы  в
# E кавитирующем потоке  минерального масла //  Наука и образование. МГТУ им.  Н.Э.
# ? Баумана. Электрон. журн. 2013. No 3. С. 31-62. DOI: 10.7463/0313.0535547
# E 3. Маргулис   М.А.,   Пильгунов   В.Н.   Свечение  и   электризация  при   течении
# E диэлектрических жидкостей в узком канале // Журнал физической химии. 2009. Т. 83,
# E No 8. С. 1585-1590.
# E 4. Маргулис М.А., Пильгунов В.Н. О механизме возникновения свечения и электризации
# E при течении жидкостей в узком канале // Журнал  физической химии. 2009. Т. 83, No
# E 10. С. 1975-1979.
# E 5. Маргулис М.А., Пильгунов В.Н. Механизм свечения и электризации жидкостей при
# E течении в узких каналах // Вестник МГТУ им. Н.Э. Баумана. Сер. Естественные
# E науки. 2010. No 1. С. 64-79. Режим доступа:
# C http://vestniken.bmstu.ru/catalog/phys/hidden/129.html  (дата обращения 01.12.2014).
# E 6. Корнилова  А.А.,  Высоцкий  В.И.,  Колдомасов  А.И.,  Yang  H.I.,  McConnell  D.B.,
# A Десятов  А.В.  Генерация  интенсивного  направленного  излучения  при  быстром
# E движении  струи  жидкости  сквозь  узкие  диэлектрические  каналы  //  Поверхность.
# ? Рентгеновские, синхротронные и нейтронные исследования. 2007. No 3. С. 55-60.
# E 7. Папок  К.К.,  Семенидо  Е.Г.  Моторные  и  реактивные  масла  и  жидкости. 4-е изд.,
# E перераб. и доп. Л.: Химия, 1963. 704 с.
# E 8. Альтшуль А.Д. Гидравлические сопротивления. 2-е изд., перераб. и доп. М.: Недра,
# C 1982. 224 с.
# E 9. Пильгунов В.Н. Исследование разрывной прочности минерального масла //  Наука и
# E образование.  МГТУ  им.  Н.Э.  Баумана.  Электрон.  журн.  2012.  No  5.  С.  1-17. DOI:
# C 10.7463/0512.0370692
# B 10. Deo R.C. Comparative Analysis of Turbulent Plane Jets from a Sharp-Edged Orifice, a Bev-
# E eled-Edge Orifice and a Radially Contoured Nozzle // Engineering and  Technology Interna-
# E tional  Journal  of  Mechanical,  Aerospace,  Industrial  and  Mechatronics  Engineering.  2013.
# C Vol. 7, no. 12. P. 1496-1505.
# B 11. De Giorgi M.G., Ficarella A., Tarantino M. Evaluating cavitation regimes in an internal ori-
# C fice at different temperatures using frequency analysis and visualization // International
# C Journal of Heat and Fluid Flow. 2013. Vol. 39. P. 160-172. DOI:
# C 10.1016/j.ijheatfluidflow.2012.11.002
# C
# C
# C Aerospace Scientific Journal of the Bauman
# C MSTU, 2015, no. 01, pp. 31–57.
# C DOI: 10.7463/aersp.0115.0775178
# C Received: 12.01.2015
# C
# C © Bau man Moscow State Technical Unversity
# C High Viscosity Liquid Flow through the Round
# C Orifices at Small Reynold’s Numbers
# B V.N. Pil'gunov
# C 1,*
# C , K.D. Efremova
# C 1
# ?
# B
# E 1Bauman Moscow State Technical University, Moscow, Russia
# ?
# C
# C Ke ywor ds: flo w process through   small   round   orifice , cavitation   on   the   sharp   inlet   edge,
# C electrodynamics properties of the die lectric liquid stream through orifice, foa ming
# C
# E The paper presents research results of the mineral oil flow process with viscosity of 30 cSt
# B through a round orifice with the sharp inlet edge of 0.9  mm in diameter. Pilot studies were con-
# B ducted using  a module from  the transparent  plexiglas  that  allowed  to  visualize  hydrodynamic
# B processes.  The intake and off-take channels of the  module with their sufficient extension had di-
# B ameter of 20 mm (24 diameters of an orifice) that allows us to consider compression of a stream
# B as perfect. Drawing the enameled nichrome  wire with a  mark as a stripping  isolation of 0.1  mm
# B width enabled  sounding  of  electric  processes  in the stream sections. Intensive  high-frequency
# B electric processes were revealed in cavitation stream. The paper gives experimental values of co-
# B efficients of  volumetric and  mass  flow at  low (150 <Re <800) Reynolds  numbers in conditions
# B of free jet and submerged orifice. Free jet at a speed exceeding 50  m/s strikes a wall, barrier,  in-
# B stalled at a distance of 100 diameters of the orifice:  the reflection from walls, barriers shot blast,
# B which caused intense foaming and conversion of oil into the two-phase mixture "fluid- combined
# B air." We  investigate the  "life cycle" of a two-phase  mixture:  flotation bubbles  in a viscous  medi-
# B um, and there was no air passes completely evolved in the dissolved state in a time not exceeding
# B 30 minutes. Volumetric analysis of the foam allowed us to estimate the percentage of volumetric
# B gas content of oil, which  was 9% at 240С and atmospheric pressure of 97.5 kPa. An explanation
# B of the possible cause cavitation edge at the end of a viscous fluid through an orifice with a sharp
# B edge - appearance  in fluid  large tensile  forces due to  the centrifugal  force on the particles of the
# B fluid streams in passing peripheral sharp edge. Experimental research data flow of a viscous fluid
# B in  the annular orifice formed sharp edge and  the surface of  the string. Detected  failure  mode ex-
# B piration free jet and conversion shareware transparent laminar jet in the turbulized intensive vor-
# B tex  formation cords.  At a differential pressure of 0.5 MPa at  the opening  swing of the electrical
# B signals  reaching 100  mV and a  width of  the  frequency range 1.2 ... 12 kHz.  The publication  re-
# B fers  to a  number of  fundamental works of  "fluid  mechanics",  given  in the bibliography  for this
# B article. The results can be taken into account in the design of throttling elements hydro devices.
# C References
# E 1. Pil'gunov V.N., Efremova K.D. Features of the Viscous Fluids Effluent Through Non-round
# E Shape  Edge Orifices. Nauka i obrazovanie MGTU im. N.E. Baumana = Science and Educa-
# E tion  of  the  Bauman  MSTU, 2015,  no.  2,  pp.  1-23.  DOI: 10.7463/0215.0758817   (in  Rus-
# C sian).
# E 2. Pil'gunov V.N.,  Efremova K.D.  Light emission and electrical process  in the cavitating  flow
# E of  mineral oil. Nauka i obrazovanie MGTU im. N.E. Baumana = Science and Education of
# C the Bauman MSTU, 2013, no. 3, pp. 31-62. DOI: 10.7463/0313.0535547   (in Russian).
# E 3. Margulis M.A., Pil'gunov  V.N. Luminescence and electrification  in a  flow of dielectric  liq-
# E uids  through  narrow  channels. Zhurnal  fizicheskoi  khimii,  2009,  vol.  83,  no.  8,  pp.  1585-
# E 1590. (English  version of  journal: Russian Journal of Physical Chemistry A, 2009,  vol. 83,
# C no. 8, pp. 1414-1418. DOI: 10.1134/S0036024409080287 ).
# E 4. Margulis M.A., Pil'gunov V.N. The mechanism of the appearance of luminescence and elec-
# E trification in liquid flows through narrow channels. Zhurnal fizicheskoi khimii, 2009, vol. 83,
# E no. 10, pp. 1975-1979. (English  version of  journal: Russian  Journal of Physical Chemistry
# C A, 2009, vol. 83, no. 10, pp. 1789-1793. DOI: 10.1134/S0036024409100288    ).
# E 5. Margulis M.A., Pil'gunov V.N. Mechanism of  Luminescence  and Electrification of Liquids
# E Flowing  Through  Narrow  C hannels. Vestnik  MGTU  im.  N.E.  Baumana.  Ser.  Estestvennye
# E nauki  =  Herald  of  the  Bauman  Moscow  State  Technical  University.  Ser.  Natural  science,
# E 2010, no. 1, pp. 64-79. Available at: http://vestniken.bmstu.ru/catalog/phys/hidden/129.html
# C , accessed 01.12.2014. (in Russian).
# C 6. Kornilova A.A., Vysotskii V.I., Koldamasov A.I., Hyun Ik Yang, Desiatov A.V. Generation
# C of intense directional radiation during the fast motion of a liquid jet through a narrow dielec-
# C tric channel. Poverkhnost'. Rentgenovskie, sinkhrotronnye i neitronnye issledovaniia, 2007,
# C no. 3, pp. 55-60. (English version of journal: Journal of Surface Investigation. X-ray, Syn-
# C chrotron and Neutron Techniques, 2007, vol. 1, iss. 2, pp. 167-171. DOI:
# C 10.1134/S1027451007020103 ).
# E 7. Papok K.K., Semenido  E.G. Motornye i reaktivnye masla i zhidkosti [Motor and jet oil and
# C liquids]. Leningrad, Khimiya Publ., 1963. 704 p. (in Russian).
# E 8. Al'tshul'  A.D. Gidravlicheskie  soprotivleniya [Hydraulics  resistance].  Moscow,  Stroiizdat
# C Publ., 1982. 224 p. (in Russian).
# E 9. Pil'gunov  V.N.  Research  of  mineral  oil  bursting  strength. Nauka  i  obrazovanie MGTU  im.
# E N.E. Baumana = Science and Education of the Bauman MSTU, 2012, no. 5, pp. 1-17. DOI:
# C 10.7463/0512.0370692     (in Russian).
# B 10. Deo R.C. Comparative Analysis of Turbulent Plane Jets from a Sharp-Edged Orifice, a Bev-
# E eled-Edge Orifice and  a  Radially Contoured Nozzle. Engineering and Technology Interna-
# E tional  Journal  of  Mechanical,  Aerospace,  Industrial  and  Mechatronics  Engineering,  2013,
# C vol. 7, no. 12, pp. 1496-1505.
# B 11. De Giorgi M.G., Ficarella A., Tarantino M. Evaluating cavitation regimes in an internal ori-
# C fice at different temperatures using frequency analysis and visualization. International Jour-
# C nal of Heat and Fluid Flow, 2013, vol. 39, pp. 160-172. DOI:
# C 10.1016/j.ijheatfluidflow.2012.11.002

# %%
data[0].label
